# %%
import pandas as pd
import glob
import openpyxl

# %%
dataframe = pd.read_excel("medjol.pl_keywords.xlsx")
important_keywords = dataframe[(dataframe['Pozycja dziś'] > 10) & (dataframe['Pozycja dziś'] < 16)]
important_keywords
# Out:
#                              Słowo kluczowe  \
# 1173               odtrucie alkoholowe cena
# 1175                      leczenie lekomani
# 1187                  narkotyki u młodzieży
# 1190     choroba alkoholowa objawy fizyczne
# 1197                   dda cechy zachowania
# ...                                     ...
# 4173           marihuana odstawienie objawy
# 4182  ile trwa przymusowe leczenie odwykowe
# 4183            jakie są rodzaje uzależnień
# 4186                 alkohol w ciąży skutki
# 4187     uzależnienie od facebooka leczenie
#
#                                                     Url  \
# 1173                        medjol.pl/detoks/alkoholowy
# 1175                       medjol.pl/leczenie/lekomanii
# 1187  medjol.pl/warto-wiedziec/narkomania/dlaczego-d...
# 1190  medjol.pl/warto-wiedziec/alkoholizm/objawy-alk...
# 1197  medjol.pl/warto-wiedziec/alkoholizm/dorosle-dz...
# ...                                                 ...
# ...
